# %% [markdown]
# <div id="capcalera">
# <p><a href="https://colab.research.google.com/github/algorismica2020/algorismica2020.github.io/blob/master/notebookscolab/Exemple.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/problemes/master/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# <p style="clear:both"><img align='left' width="300px" style="padding-right:10px;float=left" src="https://raw.githubusercontent.com/algorismica2019/problemes/master/assets/al-khwarizmi.png" >Aquest notebook complementa la teoria de l'assignatura d'<strong>Algorísmica</strong> del Grau d'Enginyeria Informàtica a la <a href="https://mat.ub.edu">Facultat de Matemàtiques i Informàtica</a> de la <a href="https://www.ub.edu">Universitat de Barcelona</a> impartida per <em>Jordi Vitrià</em> i <em>Mireia Ribera</em></p>
#
# <p>Els problemes s'ofereixen sota llicència <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode">CC-BY-NC-ND license</a>, i el codi sota <a href="https://opensource.org/licenses/MIT">Llicència MIT</a>.</p>
#
# </div>

# %% [markdown]
# # <span class="tema">(Python)</span> Programa exemple d'estructures de control, col.leccions, ús de fitxers...

# %% [markdown]
# En aquest programa fem una demostració de totes les instruccions de Python que hem estudiat fins ara. I anem comentant les diferents parts del codi per entendre-les més a fons.

# %%
def numW():
    '''
    Aquest programa calcula l'estadística de les paraules d'un document
    '''
    fname = input("Nom del document")
    text = open(fname, 'r').read()
    text = text.lower()
    for ch in '!"·$%&/()=?¿|@#¢∞¬÷÷“”≠¡{}[]+-,.;:-_><':
        text.replace(ch,' ')
    words = text.split()
    counts = {}
    for w in words:
        if w in counts:
            counts[w] = counts[w] + 1
        else:
            counts[w] = 1
    n = eval(input("Quantes paraules vols analitzar (les més freqüents)?"))
    lfreq = []
    for w in counts:
        lfreq.append((counts[w],w))
    lfreq.sort(reverse=True)
    for i in range(min(n,len(lfreq))-1):
        print(lfreq[i][1], lfreq[i][0])

# %% [markdown]
# Per a poder executar aquesta funció ens cal disposar d'un fitxer de text. El primer que fareu serà baixar-vos el text de Romeo y Julieta del projecte Gutenberg https://www.gutenberg.org/files/1112/1112.txt, anar a la part esquerra del collab (seleccionant la icona de la carpeta) i pujar el fitxer.
# Un cop fet això ja li podreu donar el nom del fitxer a la funció: 1112.txt

# %%
numW()
# Out:
# Nom del document1112.txt
# Quantes paraules vols analitzar (les més freqüents)?10
# [(862, 'the'), (84, 'project'), (26, 'gutenberg'), (11, 'ebook'), (533, 'of'), (54, 'romeo'), (764, 'and'), (17, 'juliet,'), (128, 'by'), (8, 'william'), (8, 'shakespeare'), (2, '*******************************************************************'), (253, 'this'), (47, 'was'), (55, 'one'), (1, "gutenberg's"), (15, 'early'), (3, 'files'), (2, 'produced'), (87, 'at'), (518, 'a'), (22, 'time'), (53, 'when'), (1, 'proofing'), (2, 'methods'), (1, 'tools'), (36, 'were'), (241, 'not'), (23, 'well'), (1, 'developed.'), (49, 'there'), (363, 'is'), (90, 'an'), (1, 'improved'), (1, 'edition'), (1, 'title'), (62, 'which'), (66, 'may'), (225, 'be'), (1, 'viewed'), (166, 'as'), (1, '(#100)'), (1, 'https://www.gutenberg.org/ebooks/100'), (245, 'for'), (24, 'use'), (5, 'anyone'), (2, 'anywhere'), (90, 'no'), (2, 'cost'), (300, 'with'), (5, 'almost'), (2, 'restrictions'), (2, 'whatsoever.'), (295, 'you'), (8, 'copy'), (13, 'it,'), (50, 'give'), (201, 'it'), (10, 'away'), (141, 'or'), (2, 're-use'), (14, 'under'), (21, 'terms'), (11, 'license'), (2, 'included'), (4, 'online'), (2, 'www.gutenberg.org/license'), (1, 'title:'), (27, 'juliet'), (1, 'author:'), (1, 'posting'), (2, 'date:'), (1, '25,'), (1, '2012'), (1, '[ebook'), (2, '#1112]'), (1, 'release'), (1, 'november,'), (1, '1997'), (1, '[etext'), (1, 'language:'), (1, 'english'), (1, 'character'), (16, 'set'), (1, 'encoding:'), (1, 'ascii'), (6, '***'), (2, 'start'), (1, '*project'), (4, 'proud'), (612, 'to'), (1, 'cooperate'), (11, 'world'), (1, 'library*'), (366, 'in'), (1, 'presentation'), (4, 'complete'), (26, 'works'), (112, 'your'), (2, 'reading'), (1, 'education'), (1, 'entertainment.'), (2, 'however,'), (2, 'neither'), (1, 'shareware'), (21, 'nor'), (13, 'public'), (1, 'domain.'), (2, '.'), (1, '.and'), (5, 'library'), (6, 'future'), (1, 'conditions'), (1, 'presentation.'), (1, '.no'), (3, 'charges'), (18, 'made'), (1, '*any*'), (12, 'access'), (1, 'material.'), (87, 'are'), (1, 'encouraged!!'), (2, 'like,'), (179, 'but'), (1, 'allowed!!'), (2, 'tragedy'), (5, 'trademark'), (1, '(tm)'), (1, 'inc.'), (1, '<<this'), (29, 'electronic'), (2, 'version'), (14, 'copyright'), (1, '1990-1993'), (1, 'library,'), (1, 'inc.,'), (6, 'provided'), (1, 'etext'), (1, 'carnegie'), (1, 'mellon'), (1, 'university'), (2, 'permission.'), (2, 'machine'), (3, 'readable'), (9, 'copies'), (5, 'distributed'), (121, 'so'), (15, 'long'), (52, 'such'), (1, '(1)'), (4, 'others'), (1, 'personal'), (1, 'only,'), (1, '(2)'), (4, 'used'), (1, 'commercially.'), (1, 'prohibited'), (2, 'commercial'), (7, 'distribution'), (2, 'includes'), (52, 'any'), (1, 'service'), (343, 'that'), (1, 'download'), (1, 'membership.>>'), (1, '1595'), (1, 'dramatis'), (1, 'personae'), (3, 'chorus.'), (2, 'escalus,'), (10, 'prince'), (5, 'verona.'), (8, 'paris,'), (19, 'young'), (2, 'count,'), (6, 'kinsman'), (19, 'prince.'), (13, 'montague,'), (4, 'heads'), (20, 'two'), (2, 'houses'), (2, 'variance'), (5, 'each'), (3, 'other.'), (14, 'capulet,'), (31, 'old'), (9, 'man,'), (5, 'capulet'), (1, 'family.'), (36, 'romeo,'), (12, 'son'), (6, 'montague.'), (21, 'tybalt,'), (3, 'nephew'), (26, 'lady'), (9, 'capulet.'), (10, 'mercutio,'), (7, 'friend'), (20, 'romeo.'), (5, 'benvolio,'), (27, 'friar'), (1, 'laurence,'), (2, 'franciscan.'), (3, 'john,'), (2, 'balthasar,'), (5, 'servant'), (1, 'abram,'), (1, 'sampson,'), (3, 'gregory,'), (4, 'peter,'), (7, "juliet's"), (106, 'nurse.'), (2, 'apothecary.'), (9, 'three'), (2, 'musicians.'), (2, 'officer.'), (6, 'wife'), (7, 'daughter'), (7, 'nurse'), (12, 'juliet.'), (4, 'citizens'), (2, 'verona;'), (1, 'gentlemen'), (2, 'gentlewomen'), (16, 'both'), (1, 'houses;'), (2, 'maskers,'), (1, 'torchbearers,'), (1, 'pages,'), (1, 'guards,'), (1, 'watchmen,'), (1, 'servants,'), (1, 'attendants.'), (1, 'scene.--verona;'), (7, 'mantua.'), (2, 'prologue'), (79, 'enter'), (2, 'chor.'), (1, 'households,'), (2, 'alike'), (1, 'dignity,'), (34, 'fair'), (2, 'verona,'), (50, 'where'), (74, 'we'), (11, 'lay'), (65, 'our') ...
# [(862, 'the'), (764, 'and'), (612, 'to'), (549, 'i'), (533, 'of'), (518, 'a'), (366, 'in'), (363, 'is'), (359, 'my'), (343, 'that'), (300, 'with'), (295, 'you'), (268, 'thou'), (253, 'this'), (245, 'for'), (241, 'not'), (225, 'be'), (201, 'it'), (179, 'but'), (178, 'me'), (166, 'as'), (163, 'thy'), (163, 'rom.'), (141, 'will'), (141, 'or'), (138, 'his'), (133, 'her'), (129, 'what'), (128, 'by'), (124, 'have'), (121, 'so'), (117, 'jul.'), (113, 'he'), (112, 'your'), (107, 'shall'), (106, 'nurse.'), (103, 'she'), (103, 'all'), (100, 'if'), (100, 'from'), (96, 'do'), (90, 'thee'), (90, 'no'), (90, 'an'), (87, 'at'), (87, 'are'), (84, 'project'), (83, 'on'), (80, 'o'), (79, 'good'), (79, 'enter'), (74, 'we'), (71, "i'll"), (67, 'o,'), (66, 'may'), (65, 'our'), (65, 'love'), (64, 'ben.'), (63, 'him'), (62, 'which'), (62, 'then'), (62, 'mer.'), (62, 'hath'), (59, 'they'), (58, 'how'), (58, 'here'), (58, 'am'), (56, 'some'), (56, 'more'), (55, 'one'), (54, 'would'), (54, 'romeo'), (54, 'gutenberg-tm'), (53, 'when'), (53, 'go'), (53, 'cap.'), (52, 'such'), (52, 'friar.'), (52, 'any'), (50, 'where'), (50, 'should'), (50, 'give'), (50, 'art'), (49, 'there'), (49, 'come'), (48, 'than'), (48, 'must'), (48, 'can'), (47, 'was'), (47, 'their'), (47, 'now'), (46, 'upon'), (46, 'doth'), (45, 'let'), (44, 'these'), (44, 'tell'), (43, 'make'), (41, 'too'), (41, "'tis"), (40, 'yet'), (40, 'take'), (39, 'out'), (39, 'like'), (38, 'up'), (38, 'say'), (38, 'come,'), (36, 'were'), (36, 'romeo,'), (36, 'did'), (35, 'work'), (35, 'love,'), (34, 'see'), (34, 'know'), (34, 'fair'), (33, 'them'), (33, 'man'), (32, 'me,'), (31, 'other'), (31, 'old'), (31, 'death'), (30, 'you,'), (30, 'what,'), (29, 'much'), (29, 'electronic'), (28, 'who'), (28, 'night'), (27, 'sir,'), (27, 'me.'), (27, 'juliet'), (27, 'hast'), (27, 'friar'), (26, 'works'), (26, 'wilt'), (26, 'wife.'), (26, 'well,'), (26, 'very'), (26, 'lady'), (26, 'gutenberg'), (25, 'thee,'), (25, 'scene'), (25, 'being'), (24, 'use'), (24, 'sweet'), (24, 'lady.'), (24, 'full'), (23, 'you.'), (23, 'well'), (23, 'par.'), (23, 'heaven'), (23, 'find'), (23, 'cannot'), (22, 'time'), (22, 'till'), (22, 'not,'), (22, 'hear'), (22, 'dear'), (22, 'comes'), (22, 'call'), (22, 'bid'), (21, 'without'), (21, 'tybalt,'), (21, 'tybalt'), (21, 'terms'), (21, 'nurse,'), (21, 'now,'), (21, 'nor'), (21, 'look'), (21, 'holy'), (21, 'day'), (21, 'ay,'), (21, 'and,'), (20, 'why,'), (20, 'two'), (20, 'therefore'), (20, 'stand'), (20, 'speak'), (20, 'samp.'), (20, 'romeo.'), (20, 'ere'), (20, 'been'), (19, 'young'), (19, 'why'), (19, 'us'), (19, 'true'), (19, 'stay'), (19, 'prince.'), (19, 'part'), (19, 'nay,'), (19, 'most'), (19, 'mine'), (18, 'serv.'), (18, "romeo's"), (18, 'never'), (18, 'man.'), (18, 'made'), (18, 'keep'), (18, 'him.'), (18, 'death,'), (18, 'could'), (18, 'back'), (17, 'word'), (17, 'tyb.'), (17, 'think'), (17, 'night.'), (17, 'light'), (17, 'juliet,'), (17, 'god'), (16, 'those'), (16, 'set'), (16, 'put'), (16, 'new'), (16, 'it.'), (16, 'had'), (16, 'forth'), (16, 'exeunt.'), (16, 'both'), (16, 'about'), (15, 'whose'), (15, 'romeo!'), (15, 'poor'), (15, 'no,'), (15, 'mother.'), (15, 'married'), (15, 'many'), (15, 'madam,'), (15, 'long'), (15, 'lies'), (15, 'house'), (15, 'greg.'), (15, 'go,'), (15, 'early'), (15, 'dost'), (15, 'dead'), (15, 'county'), (15, 'before'), (14, 'under'), (14, 'thee.'), (14, 'mus.'), (14, 'lord,'), (14, 'hence'), (14, 'heart'), (14, 'get'), (14, 'foundation'), (14, 'donations'), (14, 'dead,'), (14, 'day!'), (14, 'copyright'), (14, 'capulet,'), (14, 'ah,'), (14, '1.'), (13, 'within'), (13, 'still'), (13, 'so,'), (13, 'send'), (13, 'same'), (13, 'public'), (13, 'pray'), (13, 'paris'), (13, 'night,'), (13, 'montague,'), (13, 'marry,'), (13, 'makes'), (13, 'love.'), (13, 'literary'), (13, 'lie'), (13, 'leave'), (13, 'it,'), (13, 'hour'), (13, 'hand'), (13, 'fall'), (13, 'eye'), (13, 'exit.'), (13, 'even'), (13, 'archive'), (12, 'up,'), (12, 'turn'), (12, 'thine'), (12, 'then,'), (12, ' ...
# the 862
# and 764
# to 612
# i 549
# of 533
# a 518
# in 366
# is 363
# my 359

# %% [markdown]
# <div id="peu">
# <p><a href="https://colab.research.google.com/github/algorismica2020/algorismica2020.github.io/blob/master/notebookscolab/Exemple.ipynb"><img style="margin:-10px 10px 20px 0" width="150px" align="right" src="https://raw.githubusercontent.com/algorismica2019/problemes/master/assets/colab-badge.png?raw=1" alt="Obrir a Colab" title="Obrir i executar a Google Colaboratory"></a></p>
# </div>

# %% [markdown]
# La primera instrucció que no coneixem és la següent:
#
#     text = open(fname, 'r').read()
#
# de fet aquesta instrucció són dues instruccions ajuntades:
#
#     text = open(fname, 'r')
#     text.read()
#
# amb Python podem ajuntar instruccions amb el punt sempre i quan la sortida de la primera (en el nostre cas text) sigui la entrada de la segona.
#
# Amb aquestes dues instruccions obrim un fitxer a partir d'una cadena amb el nom d'aquest, el llegim i el resultat d'aquesta lectura l'assignem a la variable text, que és de tipus string.
#
# Veiem totes les instruccions relacionades amb els fitxers:

# %% [markdown]
# ## Fitxers
#
# A banda d'entrar dades per paràmetres o per teclat, podem entrar dades a partir de fitxers. En aquesta assignatura només veurem fitxers de text.
#
# ### Obrir un fitxer i tancar-lo
# Per poder treballar amb un fitxer primer de tot cal obrir-lo
#
# **Atenció**: primer cal carregar (upload) el fitxer a collab, per tal que la funció el pugui "veure".
#
# ```python
# elMeuFitxer = open("nom fitxer", "mode")
# ```
# a on nom fitxer és el nom del fitxer en el disc i mode pot ser r (read) per llegir, w (write) per escriure [si no hi ha cap fitxer això el crea] o altres que no tractarem.
#
# Per exemple:
# ```python
# elMeuFitxer = open("prova.txt", r)
# ```
# obre el fitxer prova.txt en mode lectura (només podrem llegir, no escriure)
#
# Hem de pensar sempre a tancar els fitxers un cop oberts perquè altrament es podrien produir resultats inesperats a l´hora de fer altres entrades o sortides o podriem tenir problemes de memòria.
#
# ```python
# elMeuFitxer.close()
# ```
#
# ### Escriure en un fitxer
#
# Un cop tenim el fitxer obert ja podem treballar amb ell. Per ex:
#
# ```python
# fitxer = open("fitxerprova.txt", "w")
#
# fitxer.write("Hola món\n")  # el caràcter \n indica salt de línia
# fitxer.write("Aquest és el nostre fitxer de text nou\n")
# fitxer.write("i això és una línia nova\n")
# fitxer.write("I el fitxer s'ha creat.\n")
#
# fitxer.close()
# ```
#
# I efectivament si mirem el fitxer amb un editor de text, a dintre hi veurem:
# ```python
# Hola món
# Aquest és el nostre fitxer de text nou
# i això és una línia nova
# I el fitxer s´ha creat.
# ```
#
# ### Llegir d'un fitxer
#
# Quan llegim un fitxer python ens retorna un string amb el seu contingut
#
# ```python
# file = open("fitxerprova.txt", "r")
# print(file.read())
# file.close()
# ```
#
# Que ens mostrarà:
#
# ```python
#     Hola món
#     Aquest és el nostre fitxer de text nou
#     i això és una línia nova
#     I el fitxer s'ha creat.
# ```
#
#
# o també podem optar a llegir-lo línia a línia
# ```python
# file = open("fitxerprova.txt", "r")
# print(file.readlines())
# file.close()
# ```
# Que ens mostrarà
# ```python
# ['Hola món\n', 'Aquest és el nostre fitxer de text nou\n', 'i això és una línia nova\n', 'I el fitxer s'ha creat.\n']
# ```
#
# Podem també recorrer un fitxer dins una iteració:
# ```python
# file = open("fitxerprova.txt", "r")
# for l in file:
#     print(l)
# file.close()
# ```
#
# Que ens mostrarà
# ```python
# Hola món
#
# Aquest és el nostre fitxer de text nou
#
# i això és una línia nova
#
# I el fitxer s'ha creat..
# ```
#
# ### Gestió elegant de fitxers
# Quan volem fer diverses accions de lectura sobre un fitxer podem usar l´ordre with...
#
# ```python
# with open("fitxerprova.txt") as file:
#     data = file.read()
#     do something with data
# ```
#
# amb el with obrim sempre en mode lectura, i no ens cal indicar el tancament
#
# És molt recomanable doncs usar aquesta sintaxi quan s´escau.

# %% [markdown]
# Les instruccions que segueixen ens preparen el text per poder-ne fer l'estudi estadístic; tot a minúscules i tots els caràcters estranys o puntuació convertits a ' '. Finalment, separem les paraules pels espais.
#
#
#     text = text.lower()
#     for ch in '!"·$%&/()=?¿|@#¢∞¬÷÷“”≠¡{}[]+-,.;:-_><':
#         text.replace(ch,' ')
#     words = text.split()

# %% [markdown]
# I ara creem un diccionari que associarà cada paraula (la clau) amb la seva freqüència (el valor). El primer cop que troba la paraula crea una nova entrada al diccionari, el segon i posteriors cops incrementa el seu valor
#
#     counts = {}
#     for w in words:
#         if w in counts:
#             counts[w] = counts[w] + 1
#         else:
#             counts[w] = 1

# %% [markdown]
# Acabat el diccionari, el copiem a una llista.
#
# Aquesta operació no la podem fer directe perquè volem ordenar la llista per la freqüència i per tant hem de canviar l'ordre dels elements del diccionari: primer la freqüència, després la paraula.
#
# Un cop copiada la llista, l'ordenem inversament, de major a menor.
#
# Finalment, mostrem tots els elements de la llista dins el rang demanat per l'usuari (n).
#
#
#     lfreq = []
#     for w in counts:
#         lfreq.append((counts[w],w))
#     lfreq.sort(reverse=True)
#     for i in range(min(n,len(lfreq))-1):
#         print(lfreq[i][1], lfreq[i][0])

# %% [markdown]
# **Exercici**: Reviseu el codi, i intenteu identificar les estructures de Python que hem anat treballant aquests dies. Inputs, iteracions, col.leccions, treball amb cadenes...
